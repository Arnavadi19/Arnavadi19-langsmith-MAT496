# %% [markdown]
# # Run Experiments in Playground

# %% [markdown]
# ### Setup

# %%
# You can set them inline
import os
os.environ["LANGSMITH_API_KEY"] = ""

# %%
# Or you can use a .env file
from dotenv import load_dotenv
load_dotenv(dotenv_path=".env", override=True)
# Out:
# True

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# changed system prompt to ask the same question
#
# ![image.png](attachment:image.png)

# %% [markdown]
# comparing outputs from 2 different models
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# asking an unrelated question
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Create a Dataset

# %% [markdown]
# Let's create a toy example dataset to run experiments over for a prompt

# %%
from langsmith import Client

example_inputs = [
("What color is the sky?", "The sky is blue"),
("What color is grass?", "Grass is green"),
("What color is dirt?", "Dirt is brown"),
]

client = Client()
dataset_name = "Sample Questions"

dataset = client.create_dataset(
  dataset_name=dataset_name, description="Sample questions about color",
)

inputs = [{"question": input_prompt} for input_prompt, _ in example_inputs]
outputs = [{"output": output_answer} for _, output_answer in example_inputs]

client.create_examples(
  inputs=inputs,
  outputs=outputs,
  dataset_id=dataset.id,
)

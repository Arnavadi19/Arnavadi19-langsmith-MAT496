# %% [markdown]
# using canvas
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# changing the example
# ![image.png](attachment:image.png)
